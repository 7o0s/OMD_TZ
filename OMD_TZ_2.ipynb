# %%
import requests
import json
import re
import os
from fake_useragent import UserAgent
import time

# %%
def get_random_chrome_user_agent(): #  Функция для генерации случайного user агента
    user_agent = UserAgent(browsers='chrome', os='windows', platforms='pc')
    return user_agent.random

def requestUrl(api_url): # Функция для отправки запроса (Аргументы: ссылка на API)
    ua = get_random_chrome_user_agent() # Вызов функции get_random_chrome_user_agent
    
    cookies = { # Инициализация словаря cookies с данными из DevTools
        'agreements': 'j:{"isCookieAccepted":true,"isAdultContentEnabled":false,"isAppAppInstallPromptClosed":true}',
        'TS015bfe9d': '01b7bf3690338f1e67ed07187e8f625ae19c5657590ad3aa3e7b7dd7ae134157c3f5983416eb48e31468ddd45a95d8460185f1cd287c9c504879815f85a29ede7529165434',
        '_dd_s': 'logs=1&id=89017ee7-1cdc-426c-99f1-5bbcabcf0bab&created=1724671908085&expire=1724674997268',
        'session': 'j:{"accessToken":"eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzUxMiJ9..AMB-LgvL_shdNcShGT-JJed1vmzSjOowQSQ6lldczKm-H4AHKwuCfYDw91WLPQsyGXo4yrzKZ3qBAnINr0hTYyOSAFZTL_MWotDfC4JGzbeVxb3DXcpp1iFoTTBCRpb5zZOleBkCJty2g3uj6xJ3MJhN36HEWGHkXWXnGdQlqLVXw2ve","refreshToken":"eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzUxMiJ9..AG89PILUYdjfPsqhB6o8Lv3mVtgFg16jed-dPwpl2UHvu5Pke5Z3Z23lgSnsyCWKapnU2tsgp_-FUPKmB9T4GQxAAW-0ttnRMxD9kwwxaXOJYfs2SE4e3e1WqYUaHR77kEytm9n7KMuP01BB7kEJNly0lumocKVD0pk6CpbfzltiKjBJ","accessTokenExpiredAt":1724700705051,"refreshTokenExpiredAt":1740223905051,"device":{"uuid":"8779ab79-47b2-4e6e-9393-1c56d589fe84"}}',
    }
    
    headers = { # Инициализация словаря headers с данными из DevTools
        'Accept': 'application/json, text/plain, */*',
        # 'Accept-Encoding': 'gzip, deflate, br, zstd',
        'Accept-Language': 'ru,en-US;q=0.9,en;q=0.8',
        'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzUxMiJ9..ACK0oC5-H1C1Bj-BxbB1aaSZ0yDx6rvKHZi4Ew_ETpj_vUyJm6Hsoes8V3WhzIr1_uwW4-_W3ipXsKmaral1LQogAebbQ4-vvFmmxp8uvfcu6JckWi-E9VTkAN9I5D8BURpC37XDahK1joRLqrE8W3Qk8zaPhyhkRdzuMeQdaM94f8Om',
        'User-Agent': ua,
    }
    
    response = requests.get( # Вызов функции отправления запроса GET с заголовками и куки
        api_url,
        cookies=cookies,
        headers=headers,
    )

    return response

def create_result_dict(product_url): # Функция для создания итогового словаря (Аргументы: сслыка на продукт)
    id_api = re.search(r'\d+$', url) # Поиск id продукта в ссылке с помощью регулярных выражений 
    
    api_url = f"https://www.perekrestok.ru/api/customer/1.4.1.0/catalog/product/plu{id_api.group(0)}" # Инициализация переменной api_url

    response = requestUrl(api_url) # Вызов функции requestUrl
    
    full_json = response.json() # Получение ответа из переменной response с помощью метода json()

    # Далее следует инициализации различных переменных, для получения словаря
    
    catalog_id = full_json['content']['catalogPrimaryCategory']['id'] 
    slug = full_json['content']['masterData']['slug'] 
    
    code = full_json['content']['masterData']['plu'] 
    
    # content_url = f"https://www.perekrestok.ru/cat/{catalog_id}/p/{slug}-{code}"
    content_url = product_url 

    name = full_json['content']['title']

    description = full_json['content']['description']

    grossPrice = full_json['content']['priceTag']['grossPrice']
    netPrice = full_json['content']['priceTag']['price']
    if grossPrice != None:
        price = grossPrice / 100
        price_sale = netPrice / 100
    else:
        price = netPrice / 100
        price_sale = None

    rating = full_json['content']['rating'] / 100

    comment_count = full_json['content']['reviewCount']

    brand = full_json['content']['analyticsInfo'][1]['value']

    categories = []
    categories.append(full_json['content']['primaryCategory']['title'])
    categories.append(full_json['content']['catalogPrimaryCategory']['title'])

    images = []
    for cnt in range(len(full_json['content']['images'])):
        images_dict = {"image_url": full_json['content']['images'][cnt]['cropUrlTemplate'].replace('%s', '800x800-fit')}
        images.append(images_dict)

    # Инициализация итогового словаря с данными из ответа API
    
    result_dict = {"content_url": content_url, "name": name, "code": code, "description": description, "price_sale": price_sale, "price": price, "rating": rating, "comment_count": comment_count, "brand": brand, "categories": categories, "images": images}

    return result_dict

def create_result_json(url): # Функция для сохранения итогового словаря в json файл (Аргументы: ссылка на продукт)
    result_dict = create_result_dict(url) # Вызов функции create_result_dict
    ipynb_dir = os.getcwd() # Получение пути к корневому репозиторию
    with open(f"{ipynb_dir}\Product.json", "w", encoding='utf-8') as outfile:
            outfile.write(json.dumps(result_dict, ensure_ascii=False, indent=4)) # Сохранение файла Product.json в корневой папке с словарем

# %%
url = 'https://www.perekrestok.ru/cat/117/p/tvorog-5-zelenaa-linia-180g-4249284' # Ссылка на продукт
create_result_json(url) # Вызов функции create_result_json
